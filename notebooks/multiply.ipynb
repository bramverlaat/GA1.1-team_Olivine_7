# %% [markdown]
# TEAM C

# %%
def multiply(a, b):
    return a * b

a = 5
b = 6
c = 8

print(multiply(a, b))
print(multiply(b, c))
print(multiply(a, c))
# Out:
# 30
# 48
# 40

# %%
def square(x):
    return multiply(x, x)

# %%
square(5)
# Out:
# 25
